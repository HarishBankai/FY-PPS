# %% [markdown]
# <a href="https://colab.research.google.com/github/HarishBankai/FY-PPS/blob/main/SY_IAI_28001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

A = np.array([[3, 4] ,
              [7, 6]])

if (A == A.T).all():
  print("A is symmetric")
else:
  print("A is not symmetric")
# Out:
# A is not symmetric

# %%
import numpy as np

A = np.array([[3, 4] ,
              [7, 6]])

is_symmetric = True
for i in range(2):
  for j in range(2):
    if A[i, j] != A[j,i]:
      is_symmetric = False
      break
      if not is_symmetric:
        breaK

if is_symmetric:
  print("A is symmetric")
else:
  print("A is not symmetric")
# Out:
# A is not symmetric

# %%
import numpy as np

n=int(input("Enter the size of the matrix: "))

A = np.zeros((n, n), dtype=int) # Initialize the matrix A 56 with zeros

for i in range(n):
  for j in range(n):
    A[i,j] = int(input(f"Enter element A[{i},{j}]: ")) # Changed prompt for clarity

is_symmetric = True
for i in range(n):
  for j in range(n):
    if A[i, j] != A[j,i]:
      is_symmetric = False
      break
  if not is_symmetric:
    break

if is_symmetric:
  print("A is symmetric")
else:
  print("A is not symmetric")
# Out:
# Enter the size of the matrix: 3
# Enter element A[0,0]: 1
# Enter element A[0,1]: 2
# Enter element A[0,2]: 3
# Enter element A[1,0]: 4
# Enter element A[1,1]: 5
# Enter element A[1,2]: 6
# Enter element A[2,0]: 7
# Enter element A[2,1]: 8
# Enter element A[2,2]: 9
# A is not symmetric
